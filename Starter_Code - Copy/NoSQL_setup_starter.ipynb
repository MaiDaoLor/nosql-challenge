# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with   `mongoimport --type json -d met -c uk_food --drop --jsonArray establishments.json`

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'epa', 'fruits_db', 'local', 'met', 'petsitly_marketing', 'test', 'travel_db']

# %%
# assign the uk_food database to a variable name
db = mongo['met']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['uk_food', 'artifacts', 'establishments']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['uk_food', 'artifacts', 'establishments']

# %%
# review a document in the establishments collection
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6504e9ede594807f5672bdc4'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restuarant = {
    "BusinessName":"Penang Flavours",
    "BusinessType":"Restaurant/Cafe/Canteen",
    "BusinessTypeID":"",
    "AddressLine1":"Penang Flavours",
    "AddressLine2":"146A Plumstead Rd",
    "AddressLine3":"London",
    "AddressLine4":"",
    "PostCode":"SE18 7DY",
    "Phone":"",
    "LocalAuthorityCode":"511",
    "LocalAuthorityName":"Greenwich",
    "LocalAuthorityWebSite":"http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress":"health@royalgreenwich.gov.uk",
    "scores":{
        "Hygiene":"",
        "Structural":"",
        "ConfidenceInManagement":""
    },
    "SchemeType":"FHRS",
    "geocode":{
        "longitude":"0.08384000",
        "latitude":"51.49014200"
    },
    "RightToReply":"",
    "Distance":4623.9723280747176,
    "NewRatingPending":True
}

# %%
# Insert the new restaurant into the collection
establishments.insert_one(new_restuarant)

# %%
# Check that the new restaurant was inserted
pprint(db.establishments.find_one(new_restuarant))
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('650a3c98c30ef9ffe9136ba5'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
#Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
query = {'BusinessType': "Restaurant/Cafe/Canteen"}
fields = {'BusinessTypeID': 1, 'BusinessType': 1}

results = list(establishments.find(query, fields))

pprint(results)
# Out:
# [{'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bdc5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bdce')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bdd1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bdd5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bdd7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bde7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bdec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bdf3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bdf4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bdf6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bdf9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bdfb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be09')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be11')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be12')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be18')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be1a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be1d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be1e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be1f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be22')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be25')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be27')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be29')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be2a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be30')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be33')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be35')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be38')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be3a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be3e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be3f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be47')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be48')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be4a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be4c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be50')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be51')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be56')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be57')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be59')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be5d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be5e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be62')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be64')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be65')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be6a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be6b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be70')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be73')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be75')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be76')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be7a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be7c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be80')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be88')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be8a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be8b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be92')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be94')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be96')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be98')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be9c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672be9f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bea0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bea7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672beaa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672beab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672beac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bead')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672beae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672beb0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672beb2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672beb8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672beb9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672beba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bebd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bec8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672beca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672becb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bece')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672becf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bed6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bed7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672beda')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bedb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bedc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bede')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bee6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bee8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bee9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bef3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bef9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf12')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf13')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf14')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf1f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf20')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf3c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf47')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf48')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf49')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf4b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf56')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf59')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf5a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf5b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf5d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf5e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf61')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf62')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf63')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf64')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf69')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf77')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf79')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf7c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf7d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf7e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf7f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf80')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf81')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf83')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf85')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf87')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf8b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf8e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf8f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf91')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf96')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf9a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf9b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf9c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf9d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bf9f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfa0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfa5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfaf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfb0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfb1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfb3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfb5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfb7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfbf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfc4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfc8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfcc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfcd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfd2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfd3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfd6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfd8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfe0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfe6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bfef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bff5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bff6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bff9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672bffc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c003')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c007')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c00d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c00e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c010')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c012')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c014')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c016')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c01d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c021')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c024')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c025')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c02a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c02c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c030')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c032')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c037')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c038')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c039')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c03a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c03b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c03c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c03d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c03f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c040')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c042')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c044')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c046')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c047')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c048')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c04b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c04d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c04e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c04f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c050')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c052')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c053')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c054')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c056')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c057')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c05a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c05b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c065')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c066')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c067')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c068')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c069')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c06c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c070')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c074')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c078')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c079')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c07a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c07f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c082')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c087')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c08a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c096')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0b7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0cb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0cf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0d0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0d2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0dd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0f8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c0fc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c101')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c107')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c113')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c126')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c132')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c134')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c137')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c140')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c158')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c15d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c15e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c163')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c165')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c170')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c174')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c176')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c17b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c180')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1aa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1c0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1cb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1e5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1f1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1fa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c1fc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c200')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c205')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c20c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c215')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c223')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c225')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c227')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c228')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c229')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c237')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c23d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c23e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c23f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c244')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c24a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c24e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c257')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c263')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c265')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c266')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c276')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c278')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c27e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c282')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c285')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c288')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c295')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c299')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c29b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c29d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2a1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2ac')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2ad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2bb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2bd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2c0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2c7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2c9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2cd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2cf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2d1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2d6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2da')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2e1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2e4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2e9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2ea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2ec')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2ef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2f0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2f3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2f4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2fd')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c2fe')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c300')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c303')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c307')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c309')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c30a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c30b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c311')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c318')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c325')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c32b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c32c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c33d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c340')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c341')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c342')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c344')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c345')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c347')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c352')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c355')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c356')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c357')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c359')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c35f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c367')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c368')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c36d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c36e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c371')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c372')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c374')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c377')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c37c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c37e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c381')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c382')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c393')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c396')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c39e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3a3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3b2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3b5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3b6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3ba')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3bf')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3c4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3ca')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3d4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3e2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c3f0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c400')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c403')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c404')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c408')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c409')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c40f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c42e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c431')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9ede594807f5672c43c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
# ...
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673543b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673543c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673543d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735449')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673544c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673544e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673544f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735454')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735455')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735456')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735457')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735458')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735459')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673545b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673545c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735460')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735462')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735463')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735464')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735466')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735469')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673546a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673546b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735470')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735476')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735478')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735479')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673547a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673547b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673547c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673547d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735484')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735485')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673548e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673548f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735493')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735498')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673549c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673549e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354a6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354dc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354de')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354e4')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354e5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354e6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354e8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354ea')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354ee')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354ef')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354f0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567354f2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735501')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735503')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735511')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735515')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735519')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673551b')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735525')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735526')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735527')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735529')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673552e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735534')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735536')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735539')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673553f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673554f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735553')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673555d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673555f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735563')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673556a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673556f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735570')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735579')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673557a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673557c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673557f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735585')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673558c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735590')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735591')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735592')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735593')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735596')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735597')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735598')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735599')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673559d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673559e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355a0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355a2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355a5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355a7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355a8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355a9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355ab')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355ad')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355ae')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355af')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355b0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355b3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355b8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355b9')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355be')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355c1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355c2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355c6')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355c8')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355cc')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355d0')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355d3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355df')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355e3')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355e5')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355e7')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355eb')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355ed')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f567355fa')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735604')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735605')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673560c')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673561d')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673561e')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735623')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735628')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673562a')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673562f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f56735630')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504e9eee594807f5673563f')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   '_id': ObjectId('6504f4303e98dc42f6ca8be1')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   '_id': ObjectId('6504f5853e98dc42f6ca8be2')},
#  {'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': '',
#   '_id': ObjectId('650a3c98c30ef9ffe9136ba5')}]

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
#query = {'BusinessType': "Restaurant/Cafe/Canteen"}
#fields = {'BusinessTypeID': 0, 'BusinessTypeIS': 0 }

#results = list(establishments.find_one(query,fields))
#pprint(results)

#establishments.find_one(query,fields)

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
establishments.update_one(new_restuarant,{'$set': {'BusinessTypeID': 1}})

# %%
# Confirm that the new restaurant was updated
pprint(db.establishments.find_one())
# Out:
# {'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.821311183521,
#  'FHRSID': 647177,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6PY',
#  'RatingDate': '2014-03-31T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': '4',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6504e9ede594807f5672bdc4'),
#  'geocode': {'latitude': 51.086058, 'longitude': 1.196408},
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#             'rel': 'self'}],
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 0

# %%
# Delete all documents where LocalAuthorityName is "Dover"
establishments.delete_many({'LocalAuthorityName': 'Dover'})

# %%
# Check if any remaining documents include Dover
establishments.count_documents({'LocalAuthorityName': 'Dover'})
# Out:
# 0

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('6504e9ede594807f5672bdc4'),
#  'FHRSID': 647177,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000041489',
#  'BusinessName': 'Wear Bay Bowls Club',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'AddressLine1': 'Wear Bay Road',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'PostCode': 'CT19 6PY',
#  'Phone': '',
#  'RatingValue': '4',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingDate': '2014-03-31T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 10},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 1.196408, 'latitude': 51.086058},
#  'RightToReply': '',
#  'Distance': 4591.821311183521,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/647177'}]}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
#establishments.update_many({}, [{'$set':{'$geocode': {'$toDouble': 'longitude'}}{'$geocode': {'$toDouble':'latitude'}}}])

establishments.update_many({}, [{'$set': 
                                 {'geocode.longitude': 
                                  {'$toDouble': '$geocode.longitude'}, 
                                 'geocode.latitude': {'$toDouble': '$geocode.latitude'}
                                 }
                                }]
                          )

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])

# %%
# Change the data type from String to Integer for RatingValue
establishments.update_many({}, [{'$set': 
                                 {'RatingValue': 
                                  {$},}

# %%
# Check that the coordinates and rating value are now numbers
